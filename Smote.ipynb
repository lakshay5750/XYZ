# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,weights=[0.90],random_state=42)

# %%
import pandas as pd
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
df=pd.concat([df1,df2],axis=1)

# %%
df.head()
# Out:
#          f1        f2  target
# 0  1.073546 -1.101339       0
# 1  0.755945 -1.172352       0
# 2  1.354479 -0.948528       0
# 3  3.103090  0.233485       0
# 4  1.951888 -0.270157       0

# %%
df.tail()
# Out:
#            f1        f2  target
# 995  1.713939  0.451639       1
# 996  1.509473 -0.794996       0
# 997 -2.150901 -2.989372       0
# 998  2.451647 -0.156629       0
# 999  3.641478  0.756925       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    896
# 1    104
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['f1'],df['f2'],c=df['target'])

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in e:\ananconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in e:\ananconda3\lib\site-packages (from imblearn) (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in e:\ananconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in e:\ananconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in e:\ananconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.5.1)
# Requirement already satisfied: joblib>=1.1.1 in e:\ananconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\ananconda3\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample=SMOTE()
X,y=oversample.fit_resample(df[['f1','f2']],df['target'])

# %%
X.shape
# Out:
# (1792, 2)

# %%
y.shape
# Out:
# (1792,)

# %%
len(y[y==0])
# Out:
# 896

# %%
len(y[y==1])
# Out:
# 896

# %%
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
df_oversampled=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(df_oversampled['f1'],df_oversampled['f2'],c=df_oversampled['target'])
